# %%
import pandas as ps

# %%
import matplotlib.pyplot as ml

# %%
df=ps.read_csv("raw_titles.csv")

# %%
df
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 5806 non-null   int64
#  1   id                    5806 non-null   object
#  2   title                 5805 non-null   object
#  3   type                  5806 non-null   object
#  4   release_year          5806 non-null   int64
#  5   age_certification     3196 non-null   object
#  6   runtime               5806 non-null   int64
#  7   genres                5806 non-null   object
#  8   production_countries  5806 non-null   object
#  9   seasons               2047 non-null   float64
#  10  imdb_id               5362 non-null   object
#  11  imdb_score            5283 non-null   float64
#  12  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 589.8+ KB

# %%
df.describe()
# Out:
#              index  release_year      runtime      seasons   imdb_score  \
# count  5806.000000   5806.000000  5806.000000  2047.000000  5283.000000
# mean   2902.500000   2016.013434    77.643989     2.165608     6.533447
# std    1676.192163      7.324883    39.474160     2.636207     1.160932
# min       0.000000   1945.000000     0.000000     1.000000     1.500000
# 25%    1451.250000   2015.000000    44.000000     1.000000     5.800000
# 50%    2902.500000   2018.000000    84.000000     1.000000     6.600000
# 75%    4353.750000   2020.000000   105.000000     2.000000     7.400000
# max    5805.000000   2022.000000   251.000000    42.000000     9.600000
#
#          imdb_votes
# count  5.267000e+03
# mean   2.340719e+04
# std    8.713432e+04
# min    5.000000e+00
# 25%    5.210000e+02
# 50%    2.279000e+03
# 75%    1.014400e+04
# max    2.268288e+06

# %%
df.isnull()
# Out:
#       index     id  title   type  release_year  age_certification  runtime  \
# 0     False  False  False  False         False              False    False
# 1     False  False  False  False         False              False    False
# 2     False  False  False  False         False              False    False
# 3     False  False  False  False         False              False    False
# 4     False  False  False  False         False              False    False
# ...     ...    ...    ...    ...           ...                ...      ...
# 5801  False  False  False  False         False               True    False
# 5802  False  False  False  False         False               True    False
# 5803  False  False  False  False         False               True    False
# 5804  False  False  False  False         False               True    False
# 5805  False  False  False  False         False               True    False
#
# ...

# %%
df.isnull().any()
# Out:
# index                   False
# id                      False
# title                    True
# type                    False
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# index                   0
# title                   0
# type                    0
# release_year            0
# runtime                 0
# production_countries    0
# seasons                 0
# imdb_score              0
# imdb_votes              0
# dtype: int64

# %%
corr=df.corr()

# %%
import seaborn as sns
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (5806, 13)

# %%
df.head()
# Out:
#    index        id                                title   type  release_year  \
# 0      0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1      1   tm84618                          Taxi Driver  MOVIE          1976
# 2      2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3      3   tm70993                        Life of Brian  MOVIE          1979
# 4      4  tm190788                         The Exorcist  MOVIE          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# 2                PG       91  ['comedy', 'fantasy']               ['GB']
# 3                 R       94             ['comedy']               ['GB']
# 4                 R      133             ['horror']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes
# ...

# %%
df.tail()
# Out:
#       index         id                               title   type  \
# 5801   5801  tm1014599                           Fine Wine  MOVIE
# 5802   5802  tm1108171                      Edis Starlight  MOVIE
# 5803   5803  tm1045018                               Clash  MOVIE
# 5804   5804  tm1098060                      Shadow Parties  MOVIE
# 5805   5805   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 5801          2021               NaN      100
# 5802          2021               NaN       74
# 5803          2021               NaN       88
# 5804          2021               NaN      116
# 5805          2021               NaN        0
#
#                                  genres production_countries  seasons  \
# 5801               ['romance', 'drama']               ['NG']      NaN
# 5802         ['music', 'documentation']                   []      NaN
# 5803                ['family', 'drama']         ['NG', 'CA']      NaN
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
#      age_certification  runtime  \
# ...

# %%
df.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# dtype: int64

# %%
df.drop(columns=["age_certification"],inplace=True)
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
# ...

# %%
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
# ...

# %%
df.drop(columns=["genres"],inplace=True)
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
# ...

# %%
df.drop(columns=["imdb_id"],inplace=True)
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
# ...

# %%
df
# Out:
#       index        id                             title  type  release_year  \
# 5         5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 29       29   ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47       47   ts20681                          Seinfeld  SHOW          1989
# 55       55   ts22082                      Knight Rider  SHOW          1982
# 57       57   ts21715                  Thomas & Friends  SHOW          1984
# ...     ...       ...                               ...   ...           ...
# 5758   5758  ts284885          Abla Fahita: Drama Queen  SHOW          2021
# 5768   5768  ts309235                    Christmas Flow  SHOW          2021
# 5770   5770  ts307816       Korean Cold Noodle Rhapsody  SHOW          2021
# 5785   5785  ts273317                     Pitta Kathalu  SHOW          2021
# 5796   5796  ts286386                       The Big Day  SHOW          2021
#
# ...

# %%
df.drop(columns=["id"],inplace=True)
df
# Out:
#       index                             title  type  release_year  runtime  \
# 5         5      Monty Python's Flying Circus  SHOW          1969       30
# 29       29  Monty Python's Fliegender Zirkus  SHOW          1972       43
# 47       47                          Seinfeld  SHOW          1989       24
# 55       55                      Knight Rider  SHOW          1982       51
# 57       57                  Thomas & Friends  SHOW          1984       10
# ...     ...                               ...   ...           ...      ...
# 5758   5758          Abla Fahita: Drama Queen  SHOW          2021       25
# 5768   5768                    Christmas Flow  SHOW          2021       50
# 5770   5770       Korean Cold Noodle Rhapsody  SHOW          2021       49
# 5785   5785                     Pitta Kathalu  SHOW          2021       37
# 5796   5796                       The Big Day  SHOW          2021       45
#
#      production_countries  seasons  imdb_score  imdb_votes
# ...

# %%
df.duplicated()
# Out:
# 5       False
# 29      False
# 47      False
# 55      False
# 57      False
#         ...
# 5758    False
# 5768    False
# 5770    False
# 5785    False
# 5796    False
# Length: 1670, dtype: bool

# %%
ps.options.display.max_rows=999

# %%
ps.options.display.max_rows=999
df
# Out:
#       index                             title  type  release_year  runtime  \
# 5         5      Monty Python's Flying Circus  SHOW          1969       30
# 29       29  Monty Python's Fliegender Zirkus  SHOW          1972       43
# 47       47                          Seinfeld  SHOW          1989       24
# 55       55                      Knight Rider  SHOW          1982       51
# 57       57                  Thomas & Friends  SHOW          1984       10
# ...     ...                               ...   ...           ...      ...
# 5758   5758          Abla Fahita: Drama Queen  SHOW          2021       25
# 5768   5768                    Christmas Flow  SHOW          2021       50
# 5770   5770       Korean Cold Noodle Rhapsody  SHOW          2021       49
# 5785   5785                     Pitta Kathalu  SHOW          2021       37
# 5796   5796                       The Big Day  SHOW          2021       45
#
#      production_countries  seasons  imdb_score  imdb_votes
# ...

# %%
df.loc[[5,5796,29]]
# Out:
#       index                             title  type  release_year  runtime  \
# 5         5      Monty Python's Flying Circus  SHOW          1969       30
# 5796   5796                       The Big Day  SHOW          2021       45
# 29       29  Monty Python's Fliegender Zirkus  SHOW          1972       43
#
#      production_countries  seasons  imdb_score  imdb_votes
# 5                  ['GB']      4.0         8.8     72895.0
# 5796               ['US']      2.0         4.6       327.0
# 29                     []      1.0         8.1      2144.0

# %%
for x in df.index:
    if df.loc[x,"imdb_score"]<=8.0:
        df.drop(x,inplace=True)
df
# Out:
#       index                                              title  type  \
# 5         5                       Monty Python's Flying Circus  SHOW
# 29       29                   Monty Python's Fliegender Zirkus  SHOW
# 47       47                                           Seinfeld  SHOW
# 106     106                                      Stargate SG-1  SHOW
# 110     110                                          One Piece  SHOW
# 112     112                                       Cowboy Bebop  SHOW
# 113     113                         Star Trek: Deep Space Nine  SHOW
# 116     116                                      Gilmore Girls  SHOW
# 120     120                            Neon Genesis Evangelion  SHOW
# 205     205                                             Okupas  SHOW
# 243     243                                       Breaking Bad  SHOW
# 244     244                                   The Walking Dead  SHOW
# 246     246                                      Downton Abbey  SHOW
# ...

# %%
for y in df.index:
    if df.loc[y,"seasons"]>=2:
        df.drop(y,inplace=True)
df
# Out:
#       index                                              title  type  \
# 29       29                   Monty Python's Fliegender Zirkus  SHOW
# 112     112                                       Cowboy Bebop  SHOW
# 120     120                            Neon Genesis Evangelion  SHOW
# 205     205                                             Okupas  SHOW
# 270     270                                         DEATH NOTE  SHOW
# 326     326                                      Gurren Lagann  SHOW
# 415     415  Monty Python: Almost the Truth (The Lawyer's Cut)  SHOW
# 417     417                        Ouran High School Host Club  SHOW
# 489     489                                    Vientos de agua  SHOW
# 556     556                                  Pecados capitales  SHOW
# 735     735                          Puella Magi Madoka Magica  SHOW
# 758     758                anohana: The Flower We Saw That Day  SHOW
# 783     783                       Pablo Escobar: The Drug Lord  SHOW
# ...

# %%
for i in df.index:
    if df.loc[i,"runtime"]<=10:
        df.drop(i,inplace=True)
df
# Out:
#       index                                              title  type  \
# 29       29                   Monty Python's Fliegender Zirkus  SHOW
# 112     112                                       Cowboy Bebop  SHOW
# 120     120                            Neon Genesis Evangelion  SHOW
# 205     205                                             Okupas  SHOW
# 270     270                                         DEATH NOTE  SHOW
# 326     326                                      Gurren Lagann  SHOW
# 415     415  Monty Python: Almost the Truth (The Lawyer's Cut)  SHOW
# 417     417                        Ouran High School Host Club  SHOW
# 489     489                                    Vientos de agua  SHOW
# 556     556                                  Pecados capitales  SHOW
# 735     735                          Puella Magi Madoka Magica  SHOW
# 758     758                anohana: The Flower We Saw That Day  SHOW
# 783     783                       Pablo Escobar: The Drug Lord  SHOW
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="scatter",x="imdb_score",y="imdb_votes")
ml.show()

# %%
data=ps.DataFrame(df)
x=list(data.imdb_score)
y=list(data.imdb_votes)
ml.bar(x,y)
ml.xlabel("imdb_score")
ml.ylabel("imdb_votes")
ml.show()

# %%
df["runtime"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dff=ps.read_csv("raw_titles.csv")
dff
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# ...

# %%
dff.isnull().any()
# Out:
# index                   False
# id                      False
# title                    True
# type                    False
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# dtype: bool

# %%
mean=dff["imdb_votes"].mean()
dff["imdb_votes"].fillna(mean,inplace=True)
dff
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# ...

# %%
dff.isnull().any()
# Out:
# index                   False
# id                      False
# title                    True
# type                    False
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes              False
# dtype: bool

# %%
mode=dff["imdb_score"].mode()[0]
dff["imdb_score"].fillna(mode,inplace=True)

# %%
dff.isnull().any()
# Out:
# index                   False
# id                      False
# title                    True
# type                    False
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score              False
# imdb_votes              False
# dtype: bool

# %%
df.plot.bar(x="imdb_votes",y="imdb_score")
# Out:
# <AxesSubplot:xlabel='imdb_votes'>

# %%
df.head(10).plot.bar(x="release_year",y="imdb_score" , ylabel="imdb_score")
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='imdb_score'>
